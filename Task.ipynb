# %% [markdown]
# Netflix Shows & Movies Analysis:

# %% [markdown]
# Part 1 – Basic Data Understanding (Pandas)

# %% [markdown]
# Load the CSV file into a Pandas DataFrame.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('C:/Users/kishore/AI WORKFORCE DAY 13/netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %% [markdown]
# Display the first 10 rows of the dataset.

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
#                                                 cast  \
# 0                                                NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
#
#                                              country          date_added  \
# 0                                      United States  September 25, 2021
# 1                                       South Africa  September 24, 2021
# 2                                                NaN  September 24, 2021
# 3                                                NaN  September 24, 2021
# 4                                              India  September 24, 2021
# 5                                                NaN  September 24, 2021
# 6                                                NaN  September 24, 2021
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
# 9                                      United States  September 24, 2021
#
#    release_year rating   duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# 3          2021  TV-MA   1 Season
# 4          2021  TV-MA  2 Seasons
# 5          2021  TV-MA   1 Season
# 6          2021     PG     91 min
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
# 9          2021  PG-13    104 min
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
# 6                           Children & Family Movies
# 7   Dramas, Independent Movies, International Movies
# 8                       British TV Shows, Reality TV
# 9                                   Comedies, Dramas
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
# 5  The arrival of a charismatic young priest brin...
# 6  Equestria's divided. But a bright-eyed hero be...
# 7  On a photo shoot in Ghana, an American model s...
# 8  A talented batch of amateur bakers face off in...
# 9  A woman adjusting to life after a loss contend...

# %% [markdown]
# Show the shape, column names, and data types.

# %%
print(f'Shape:{df.shape}')
print(f'Columns:{df.columns}')
print(f'Data_Types:{df.dtypes}')
# Out:
# Shape:(8807, 12)
# Columns:Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')
# Data_Types:show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
print(df.isnull().sum())
print(df.duplicated().sum())
df.dropna(inplace=True)
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64
# 0

# %% [markdown]
# Use .describe() for numerical and categorical columns.

# %%
print(df.describe(include=['object']))  #Categorical
print(df.describe())  #numerical
# Out:
#        show_id   type    title                director         cast  \
# count     5332   5332     5332                    5332         5332
# unique    5332      2     5332                    3945         5200
# top         s8  Movie  Sankofa  Raúl Campos, Jan Suter  Samuel West
# freq         1   5185        1                      18           10
#
#               country       date_added rating duration  \
# count            5332             5332   5332     5332
# unique            604             1453     14      198
# top     United States  January 1, 2020  TV-MA   94 min
# freq             1846               92   1822      135
#
#                            listed_in  \
# count                           5332
# unique                           335
# top     Dramas, International Movies
# freq                             336
#
#                                               description
# count                                                5332
# unique                                               5321
# top     On India's Independence Day, a zany mishap in ...
# freq                                                    2
#        release_year
# count   5332.000000
# mean    2012.742123
# std        9.625831
# min     1942.000000
# 25%     2011.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2021.000000

# %% [markdown]
# Get the number of unique values for each column.

# %%
df.nunique()
# Out:
# show_id         5332
# type               2
# title           5332
# director        3945
# cast            5200
# country          604
# date_added      1453
# release_year      72
# rating            14
# duration         198
# listed_in        335
# description     5321
# dtype: int64

# %% [markdown]
# Display the most frequent value in the country column.

# %%
df['country'].mode()
# Out:
# 0    United States
# Name: country, dtype: object

# %% [markdown]
# Part 2 – EDA (Exploratory Data Analysis)

# %% [markdown]
# Plot a bar chart for the count of Movies vs TV Shows.

# %%
import seaborn as sns
sns.countplot(data=df, x='type')
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %% [markdown]
# Find the top 10 countries producing the most content.

# %%
df['country'].value_counts().head(10)
# Out:
# country
# United States     1846
# India              875
# United Kingdom     183
# Canada             107
# Spain               91
# Egypt               90
# Nigeria             88
# Japan               83
# Turkey              79
# Indonesia           76
# Name: count, dtype: int64

# %% [markdown]
# Find the top 10 most common genres in listed_in.

# %%
df1=df['listed_in'].str.split(',').explode()
df1=df1.str.strip()
print(df1.value_counts().head(10))
# Out:
# listed_in
# International Movies        2369
# Dramas                      2293
# Comedies                    1553
# Action & Adventure           806
# Independent Movies           740
# Romantic Movies              579
# Thrillers                    547
# Children & Family Movies     503
# Documentaries                391
# Horror Movies                336
# Name: count, dtype: int64

# %% [markdown]
# Scatter plot: release_year vs count of titles.

# %%
year_count=df['release_year'].value_counts()
plt.scatter(year_count.index,year_count.values)
plt.xlabel('release_year')
plt.ylabel('count of titles')
plt.title('release_year vs count of titles')
# Out:
# Text(0.5, 1.0, 'release_year vs count of titles')

# %% [markdown]
# Create a histogram of movie durations (in minutes).

# %%
movies=df[df['type']=='Movie']
movies_duration=movies['duration'].str.replace(' min','').astype(int)
sns.histplot(x=movies_duration,kde=True)
# Out:
# <Axes: xlabel='duration', ylabel='Count'>

# %% [markdown]
# Bar chart of the number of titles added per year (based on date_added).

# %%
df['date_added'] = df['date_added'].str.strip()
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
sns.barplot(x=df['date_added'].dt.year.value_counts().index, y=df['date_added'].dt.year.value_counts().values, palette='viridis')
# Out:
# C:\Users\kishore\AppData\Local\Temp\ipykernel_11480\3294650308.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['date_added'].dt.year.value_counts().index, y=df['date_added'].dt.year.value_counts().values, palette='viridis')
# <Axes: xlabel='date_added'>

# %% [markdown]
# Find the year with the highest number of releases.

# %%
df['type'].value_counts().head(1)
# Out:
# type
# Movie    5185
# Name: count, dtype: int64

# %% [markdown]
# Part 3 – Statistics

# %% [markdown]
# Calculate the mean, median, mode of release_year.

# %%
print(f'Mean:{df['release_year'].mean()}')
print(f'Median:{df['release_year'].median()}')
print(f'Mode:{df['release_year'].mode()}')
# Out:
# Mean:2012.7421230307577
# Median:2016.0
# Mode:0    2017
# Name: release_year, dtype: int64

# %% [markdown]
# Find the variance and standard deviation of release_year.

# %%
print(f'Variance:{df['release_year'].var}')
print(f'Standard deviation:{df['release_year'].std}')
# Out:
# Variance:<bound method Series.var of 7       1993
# 8       2021
# 9       2021
# 12      2021
# 24      1998
#         ...
# 8801    2015
# 8802    2007
# 8804    2009
# 8805    2006
# 8806    2015
# Name: release_year, Length: 5332, dtype: int64>
# Standard deviation:<bound method Series.std of 7       1993
# 8       2021
# 9       2021
# 12      2021
# 24      1998
#         ...
# 8801    2015
# 8802    2007
# 8804    2009
# 8805    2006
# 8806    2015
# Name: release_year, Length: 5332, dtype: int64>

# %% [markdown]
# Percentage of titles added in the last 5 years.

# %%
titles=df['date_added'].dt.year
title=titles.sort_values(ascending=False)
per=title.value_counts().head(5)
print(f'{(per.sum()/len(df))*100:.2f}')
# Out:
# 94.50

# %% [markdown]
# Find the most common rating for Movies and TV Shows separately.

# %%
most_common_ratings = df.groupby('type')['rating'].apply(lambda x: x.value_counts().idxmax())
print(most_common_ratings)
# Out:
# type
# Movie      TV-MA
# TV Show    TV-MA
# Name: rating, dtype: object

# %% [markdown]
# Part 4 – Linear Algebra & NumPy

# %% [markdown]
# Create a NumPy array of release_year.

# %%
release_year=df['release_year'].to_numpy()
release_year
# Out:
# array([1993, 2021, 2021, ..., 2009, 2006, 2015], shape=(5332,))

# %% [markdown]
# Create a NumPy binary array for is_movie (1 if type=Movie else 0).

# %%
is_movie=np.where(df['type'] == 'Movie',1,0)
is_movie
# Out:
# array([1, 0, 1, ..., 1, 1, 1], shape=(5332,))

# %% [markdown]
# Perform vector addition of release_year array and is_movie array.

# %%
add=release_year+is_movie
add
# Out:
# array([1994, 2021, 2022, ..., 2010, 2007, 2016], shape=(5332,))

# %% [markdown]
# Compute the dot product of release_year and is_movie arrays.

# %%
dot=release_year*is_movie
dot
# Out:
# array([1993,    0, 2021, ..., 2009, 2006, 2015], shape=(5332,))

# %% [markdown]
# Create a feature matrix with [release_year, is_movie] and multiply with weights [0.6, 0.4].

# %%
feature=np.column_stack((release_year,is_movie))
weights=[0.6,0.4]
mul=feature@weights
mul
# Out:
# array([1196.2, 1212.6, 1213. , ..., 1205.8, 1204. , 1209.4], shape=(5332,))

# %% [markdown]
# Normalize the release_year column using vector normalization.

# %%
norm=np.linalg.norm(release_year)
normalized=release_year/norm
print(normalized)
# Out:
# [0.01356029 0.01375081 0.01375081 ... 0.01366916 0.01364875 0.01370998]

# %%
Part 5 – Calculus

# %% [markdown]
# Assume a function:
#  Popularity_Score = (is_movie×release_year) + 0.5×(release_year−2000)^2
#  Find the derivative with respect to release_year.

# %%
import sympy as sp
release_year=sp.symbols('release_year')
is_movie=sp.symbols('is_movie')
Popularity_Score=(is_movie * release_year)+0.5*(release_year - 2000)**2
print(sp.diff(Popularity_Score,release_year))
# Out:
# is_movie + 1.0*release_year - 2000.0

# %% [markdown]
# Part 6 – Feature Engineering

# %% [markdown]
# Create content_age = 2025 - release_year.

# %% [markdown]
# Check for missing values and duplicates.

# %%
df['content_age']=2025-df['release_year']
df
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...                                                 ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 country date_added  \
# 7     United States, Ghana, Burkina Faso, United Kin... 2021-09-24
# 8                                        United Kingdom 2021-09-24
# 9                                         United States 2021-09-24
# 12                              Germany, Czech Republic 2021-09-23
# 24                                                India 2021-09-21
# ...                                                 ...        ...
# 8801                       United Arab Emirates, Jordan 2016-03-09
# 8802                                      United States 2019-11-20
# 8804                                      United States 2019-11-01
# 8805                                      United States 2020-01-11
# 8806                                              India 2019-03-02
#
#       release_year rating   duration  \
# 7             1993  TV-MA    125 min
# 8             2021  TV-14  9 Seasons
# 9             2021  PG-13    104 min
# 12            2021  TV-MA    127 min
# 24            1998  TV-14    166 min
# ...            ...    ...        ...
# 8801          2015  TV-MA     96 min
# 8802          2007      R    158 min
# 8804          2009      R     88 min
# 8805          2006     PG     88 min
# 8806          2015  TV-14    111 min
#
#                                              listed_in  \
# 7     Dramas, Independent Movies, International Movies
# 8                         British TV Shows, Reality TV
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# 24     Comedies, International Movies, Romantic Movies
# ...                                                ...
# 8801           Dramas, International Movies, Thrillers
# 8802                    Cult Movies, Dramas, Thrillers
# 8804                           Comedies, Horror Movies
# 8805                Children & Family Movies, Comedies
# 8806    Dramas, International Movies, Music & Musicals
#
#                                             description  content_age
# 7     On a photo shoot in Ghana, an American model s...           32
# 8     A talented batch of amateur bakers face off in...            4
# 9     A woman adjusting to life after a loss contend...            4
# 12    After most of her family is murdered in a terr...            4
# 24    When the father of the man she loves insists t...           27
# ...                                                 ...          ...
# 8801  Recovering alcoholic Talal wakes up inside a s...           10
# 8802  A political cartoonist, a crime reporter and a...           18
# 8804  Looking to survive in a world taken over by zo...           16
# 8805  Dragged from civilian life, a former superhero...           19
# 8806  A scrappy but poor boy worms his way into a ty...           10
#
# [5332 rows x 13 columns]

# %% [markdown]
# Create is_movie column (1 if type='Movie', else 0).

# %%
df['is_movie']=np.where(df['type'] == 'Movie', 1, 0)
df
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...                                                 ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 country date_added  \
# 7     United States, Ghana, Burkina Faso, United Kin... 2021-09-24
# 8                                        United Kingdom 2021-09-24
# 9                                         United States 2021-09-24
# 12                              Germany, Czech Republic 2021-09-23
# 24                                                India 2021-09-21
# ...                                                 ...        ...
# 8801                       United Arab Emirates, Jordan 2016-03-09
# 8802                                      United States 2019-11-20
# 8804                                      United States 2019-11-01
# 8805                                      United States 2020-01-11
# 8806                                              India 2019-03-02
#
#       release_year rating   duration  \
# 7             1993  TV-MA    125 min
# 8             2021  TV-14  9 Seasons
# 9             2021  PG-13    104 min
# 12            2021  TV-MA    127 min
# 24            1998  TV-14    166 min
# ...            ...    ...        ...
# 8801          2015  TV-MA     96 min
# 8802          2007      R    158 min
# 8804          2009      R     88 min
# 8805          2006     PG     88 min
# 8806          2015  TV-14    111 min
#
#                                              listed_in  \
# 7     Dramas, Independent Movies, International Movies
# 8                         British TV Shows, Reality TV
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# 24     Comedies, International Movies, Romantic Movies
# ...                                                ...
# 8801           Dramas, International Movies, Thrillers
# 8802                    Cult Movies, Dramas, Thrillers
# 8804                           Comedies, Horror Movies
# 8805                Children & Family Movies, Comedies
# 8806    Dramas, International Movies, Music & Musicals
#
#                                             description  content_age  is_movie
# 7     On a photo shoot in Ghana, an American model s...           32         1
# 8     A talented batch of amateur bakers face off in...            4         0
# 9     A woman adjusting to life after a loss contend...            4         1
# 12    After most of her family is murdered in a terr...            4         1
# 24    When the father of the man she loves insists t...           27         1
# ...                                                 ...          ...       ...
# 8801  Recovering alcoholic Talal wakes up inside a s...           10         1
# 8802  A political cartoonist, a crime reporter and a...           18         1
# 8804  Looking to survive in a world taken over by zo...           16         1
# 8805  Dragged from civilian life, a former superhero...           19         1
# 8806  A scrappy but poor boy worms his way into a ty...           10         1
#
# [5332 rows x 14 columns]

# %% [markdown]
# Create recent_release (1 if release_year >= 2020, else 0).

# %%
df['recent_release']=np.where(df['release_year']>=202,1,0)
df
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...                                                 ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 country date_added  \
# 7     United States, Ghana, Burkina Faso, United Kin... 2021-09-24
# 8                                        United Kingdom 2021-09-24
# 9                                         United States 2021-09-24
# 12                              Germany, Czech Republic 2021-09-23
# 24                                                India 2021-09-21
# ...                                                 ...        ...
# 8801                       United Arab Emirates, Jordan 2016-03-09
# 8802                                      United States 2019-11-20
# 8804                                      United States 2019-11-01
# 8805                                      United States 2020-01-11
# 8806                                              India 2019-03-02
#
#       release_year rating   duration  \
# 7             1993  TV-MA    125 min
# 8             2021  TV-14  9 Seasons
# 9             2021  PG-13    104 min
# 12            2021  TV-MA    127 min
# 24            1998  TV-14    166 min
# ...            ...    ...        ...
# 8801          2015  TV-MA     96 min
# 8802          2007      R    158 min
# 8804          2009      R     88 min
# 8805          2006     PG     88 min
# 8806          2015  TV-14    111 min
#
#                                              listed_in  \
# 7     Dramas, Independent Movies, International Movies
# 8                         British TV Shows, Reality TV
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# 24     Comedies, International Movies, Romantic Movies
# ...                                                ...
# 8801           Dramas, International Movies, Thrillers
# 8802                    Cult Movies, Dramas, Thrillers
# 8804                           Comedies, Horror Movies
# 8805                Children & Family Movies, Comedies
# 8806    Dramas, International Movies, Music & Musicals
#
#                                             description  content_age  \
# 7     On a photo shoot in Ghana, an American model s...           32
# 8     A talented batch of amateur bakers face off in...            4
# 9     A woman adjusting to life after a loss contend...            4
# 12    After most of her family is murdered in a terr...            4
# 24    When the father of the man she loves insists t...           27
# ...                                                 ...          ...
# 8801  Recovering alcoholic Talal wakes up inside a s...           10
# 8802  A political cartoonist, a crime reporter and a...           18
# 8804  Looking to survive in a world taken over by zo...           16
# 8805  Dragged from civilian life, a former superhero...           19
# 8806  A scrappy but poor boy worms his way into a ty...           10
#
#       is_movie  recent_release
# 7            1               1
# 8            0               1
# 9            1               1
# 12           1               1
# 24           1               1
# ...        ...             ...
# 8801         1               1
# 8802         1               1
# 8804         1               1
# 8805         1               1
# 8806         1               1
#
# [5332 rows x 15 columns]

# %% [markdown]
# Create num_genres = count of genres in listed_in.

# %%
df['num_genres'] = df['listed_in'].apply(lambda x: len(x.split(',')))
df
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...                                                 ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 country date_added  \
# 7     United States, Ghana, Burkina Faso, United Kin... 2021-09-24
# 8                                        United Kingdom 2021-09-24
# 9                                         United States 2021-09-24
# 12                              Germany, Czech Republic 2021-09-23
# 24                                                India 2021-09-21
# ...                                                 ...        ...
# 8801                       United Arab Emirates, Jordan 2016-03-09
# 8802                                      United States 2019-11-20
# 8804                                      United States 2019-11-01
# 8805                                      United States 2020-01-11
# 8806                                              India 2019-03-02
#
#       release_year rating   duration  \
# 7             1993  TV-MA    125 min
# 8             2021  TV-14  9 Seasons
# 9             2021  PG-13    104 min
# 12            2021  TV-MA    127 min
# 24            1998  TV-14    166 min
# ...            ...    ...        ...
# 8801          2015  TV-MA     96 min
# 8802          2007      R    158 min
# 8804          2009      R     88 min
# 8805          2006     PG     88 min
# 8806          2015  TV-14    111 min
#
#                                              listed_in  \
# 7     Dramas, Independent Movies, International Movies
# 8                         British TV Shows, Reality TV
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# 24     Comedies, International Movies, Romantic Movies
# ...                                                ...
# 8801           Dramas, International Movies, Thrillers
# 8802                    Cult Movies, Dramas, Thrillers
# 8804                           Comedies, Horror Movies
# 8805                Children & Family Movies, Comedies
# 8806    Dramas, International Movies, Music & Musicals
#
#                                             description  content_age  \
# 7     On a photo shoot in Ghana, an American model s...           32
# 8     A talented batch of amateur bakers face off in...            4
# 9     A woman adjusting to life after a loss contend...            4
# 12    After most of her family is murdered in a terr...            4
# 24    When the father of the man she loves insists t...           27
# ...                                                 ...          ...
# 8801  Recovering alcoholic Talal wakes up inside a s...           10
# 8802  A political cartoonist, a crime reporter and a...           18
# 8804  Looking to survive in a world taken over by zo...           16
# 8805  Dragged from civilian life, a former superhero...           19
# 8806  A scrappy but poor boy worms his way into a ty...           10
#
#       is_movie  recent_release  num_genres
# 7            1               1           3
# 8            0               1           2
# 9            1               1           2
# 12           1               1           2
# 24           1               1           3
# ...        ...             ...         ...
# 8801         1               1           3
# 8802         1               1           3
# 8804         1               1           2
# 8805         1               1           2
# 8806         1               1           3
#
# [5332 rows x 16 columns]

# %% [markdown]
# Rank titles into quartiles based on release_year.

# %%
df['year_quartile'] = pd.qcut(df['release_year'], 4, labels=[1, 2, 3, 4])
df
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...                                                 ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 country date_added  \
# 7     United States, Ghana, Burkina Faso, United Kin... 2021-09-24
# 8                                        United Kingdom 2021-09-24
# 9                                         United States 2021-09-24
# 12                              Germany, Czech Republic 2021-09-23
# 24                                                India 2021-09-21
# ...                                                 ...        ...
# 8801                       United Arab Emirates, Jordan 2016-03-09
# 8802                                      United States 2019-11-20
# 8804                                      United States 2019-11-01
# 8805                                      United States 2020-01-11
# 8806                                              India 2019-03-02
#
#       release_year rating   duration  \
# 7             1993  TV-MA    125 min
# 8             2021  TV-14  9 Seasons
# 9             2021  PG-13    104 min
# 12            2021  TV-MA    127 min
# 24            1998  TV-14    166 min
# ...            ...    ...        ...
# 8801          2015  TV-MA     96 min
# 8802          2007      R    158 min
# 8804          2009      R     88 min
# 8805          2006     PG     88 min
# 8806          2015  TV-14    111 min
#
#                                              listed_in  \
# 7     Dramas, Independent Movies, International Movies
# 8                         British TV Shows, Reality TV
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# 24     Comedies, International Movies, Romantic Movies
# ...                                                ...
# 8801           Dramas, International Movies, Thrillers
# 8802                    Cult Movies, Dramas, Thrillers
# 8804                           Comedies, Horror Movies
# 8805                Children & Family Movies, Comedies
# 8806    Dramas, International Movies, Music & Musicals
#
#                                             description  content_age  \
# 7     On a photo shoot in Ghana, an American model s...           32
# 8     A talented batch of amateur bakers face off in...            4
# 9     A woman adjusting to life after a loss contend...            4
# 12    After most of her family is murdered in a terr...            4
# 24    When the father of the man she loves insists t...           27
# ...                                                 ...          ...
# 8801  Recovering alcoholic Talal wakes up inside a s...           10
# 8802  A political cartoonist, a crime reporter and a...           18
# 8804  Looking to survive in a world taken over by zo...           16
# 8805  Dragged from civilian life, a former superhero...           19
# 8806  A scrappy but poor boy worms his way into a ty...           10
#
#       is_movie  recent_release  num_genres year_quartile
# 7            1               1           3             1
# 8            0               1           2             4
# 9            1               1           2             4
# 12           1               1           2             4
# 24           1               1           3             1
# ...        ...             ...         ...           ...
# 8801         1               1           3             2
# 8802         1               1           3             1
# 8804         1               1           2             1
# 8805         1               1           2             1
# 8806         1               1           3             2
#
# [5332 rows x 17 columns]

# %% [markdown]
# Part 7 – SQL Simulation in Pandas

# %% [markdown]
# Select all titles where type = 'Movie' and release_year > 2015.

# %%
df2=df[(df['type']=='Movie') & (df['release_year']>2015)]
df2
# Out:
#      show_id   type                      title               director  \
# 9        s10  Movie               The Starling         Theodore Melfi
# 12       s13  Movie               Je Suis Karl    Christian Schwochow
# 38       s39  Movie        Birth of the Dragon           George Nolfi
# 73       s74  Movie               King of Boys           Kemi Adetiba
# 81       s82  Movie                       Kate  Cedric Nicolas-Troyan
# ...      ...    ...                        ...                    ...
# 8781   s8782  Movie    Yo-Kai Watch: The Movie            Mark Risley
# 8782   s8783  Movie                Yoga Hosers            Kevin Smith
# 8786   s8787  Movie               You Can Tutu            James Brown
# 8787   s8788  Movie  You Can’t Fight Christmas            Kenny Young
# 8794   s8795  Movie                     اشتباك           Mohamed Diab
#
#                                                    cast  \
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 38    Billy Magnussen, Ron Yuan, Qu Jingjing, Terry ...
# 73    Sola Sobowale, Adesua Etomi, Remilekun "Remini...
# 81    Mary Elizabeth Winstead, Jun Kunimura, Woody H...
# ...                                                 ...
# 8781  Johnny Yong Bosch, Joey D'Auria, Alicyn Packar...
# 8782  Harley Quinn Smith, Lily-Rose Depp, Johnny Dep...
# 8786  Lily O'Regan, Jeannettsy Enriquez Borges, Joel...
# 8787  Brely Evans, Andra Fuller, Persia White, Porsc...
# 8794  Nelly Karim, Hany Adel, Tarek Abdel Aziz, Ahme...
#
#                            country date_added  release_year rating duration  \
# 9                    United States 2021-09-24          2021  PG-13  104 min
# 12         Germany, Czech Republic 2021-09-23          2021  TV-MA  127 min
# 38    China, Canada, United States 2021-09-16          2017  PG-13   96 min
# 73                         Nigeria 2021-09-14          2018  TV-MA  182 min
# 81                   United States 2021-09-10          2021      R  106 min
# ...                            ...        ...           ...    ...      ...
# 8781          Japan, United States 2016-12-01          2016  TV-Y7   96 min
# 8782                 United States 2016-12-02          2016  PG-13   88 min
# 8786                United Kingdom 2017-12-31          2017   TV-G   87 min
# 8787                 United States 2017-12-19          2017  TV-PG   85 min
# 8794                 Egypt, France 2018-10-11          2016  TV-14   98 min
#
#                                              listed_in  \
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# 38                          Action & Adventure, Dramas
# 73                        Dramas, International Movies
# 81                                  Action & Adventure
# ...                                                ...
# 8781          Anime Features, Children & Family Movies
# 8782       Comedies, Horror Movies, Independent Movies
# 8786                          Children & Family Movies
# 8787                         Comedies, Romantic Movies
# 8794  Dramas, Independent Movies, International Movies
#
#                                             description  content_age  \
# 9     A woman adjusting to life after a loss contend...            4
# 12    After most of her family is murdered in a terr...            4
# 38    A young Bruce Lee angers kung fu traditionalis...            8
# 73    When a powerful businesswoman’s political ambi...            7
# 81    Slipped a fatal poison on her final job, a rut...            4
# ...                                                 ...          ...
# 8781  Nate's special Yo-Kai Watch is missing. He tra...            9
# 8782  With an all-important high school party at sta...            9
# 8786  A gifted young ballet dancer struggles to find...            8
# 8787  After stepping in to revitalize his family's h...            8
# 8794  Amid the tumult following Egyptian President M...            9
#
#       is_movie  recent_release  num_genres year_quartile
# 9            1               1           2             4
# 12           1               1           2             4
# 38           1               1           2             3
# 73           1               1           2             3
# 81           1               1           1             4
# ...        ...             ...         ...           ...
# 8781         1               1           2             2
# 8782         1               1           3             2
# 8786         1               1           1             3
# 8787         1               1           2             3
# 8794         1               1           3             2
#
# [2889 rows x 17 columns]

# %% [markdown]
# Sort movies by release_year descending and title ascending.

# %%
movies.sort_values(by=['release_year', 'title'], ascending=[True, True])
# Out:
#      show_id   type                    title  \
# 8205   s8206  Movie     The Battle of Midway
# 8640   s8641  Movie         Tunisian Victory
# 7219   s7220  Movie  Know Your Enemy - Japan
# 7294   s7295  Movie       Let There Be Light
# 8587   s8588  Movie              Thunderbolt
# ...      ...    ...                      ...
# 739     s740  Movie              Wish Dragon
# 1412   s1413  Movie                 Wish You
# 1319   s1320  Movie           Xico's Journey
# 765     s766  Movie                   Xtreme
# 1218   s1219  Movie                  YES DAY
#
#                                                director  \
# 8205                                          John Ford
# 8640  Frank Capra, John Huston, Hugh Stewart, Roy Bo...
# 7219                           Frank Capra, Joris Ivens
# 7294                                        John Huston
# 8587                        William Wyler, John Sturges
# ...                                                 ...
# 739                                     Chris Appelhans
# 1412                                        Sung Do-jun
# 1319                               Eric D. Cabello Díaz
# 765                                     Daniel Benmayor
# 1218                                      Miguel Arteta
#
#                                                    cast  \
# 8205                          Henry Fonda, Jane Darwell
# 8640                                   Burgess Meredith
# 7219                        Walter Huston, Dana Andrews
# 7294                                      Walter Huston
# 8587                       James Stewart, Lloyd Bridges
# ...                                                 ...
# 739   Jimmy Wong, John Cho, Constance Wu, Will Yun L...
# 1412                     Kang In-soo, Lee Sang, Soo-bin
# 1319  Verónica Alva, Pablo Gama Iturrarán “Mago Gami...
# 765   Teo García, Óscar Jaenada, Óscar Casas, Andrea...
# 1218  Jennifer Garner, Edgar Ramírez, Jenna Ortega, ...
#
#                             country         date_added  release_year rating  \
# 8205                  United States     March 31, 2017          1942  TV-14
# 8640  United States, United Kingdom     March 31, 2017          1944  TV-14
# 7219                  United States     March 31, 2017          1945  TV-14
# 7294                  United States     March 31, 2017          1946  TV-PG
# 8587                  United States     March 31, 2017          1947  TV-PG
# ...                             ...                ...           ...    ...
# 739    China, United States, Canada      June 11, 2021          2021     PG
# 1412                    South Korea   January 15, 2021          2021  TV-PG
# 1319                         Mexico  February 12, 2021          2021  TV-Y7
# 765                           Spain       June 4, 2021          2021  TV-MA
# 1218                  United States     March 12, 2021          2021     PG
#
#      duration                                   listed_in  \
# 8205   18 min               Classic Movies, Documentaries
# 8640   76 min               Classic Movies, Documentaries
# 7219   63 min               Classic Movies, Documentaries
# 7294   58 min               Classic Movies, Documentaries
# 8587   42 min               Classic Movies, Documentaries
# ...       ...                                         ...
# 739   102 min          Children & Family Movies, Comedies
# 1412  102 min  Dramas, International Movies, LGBTQ Movies
# 1319   87 min                    Children & Family Movies
# 765   112 min    Action & Adventure, International Movies
# 1218   90 min          Children & Family Movies, Comedies
#
#                                             description
# 8205  Director John Ford captures combat footage of ...
# 8640  British and American troops join forces to lib...
# 7219  Though culturally insensitive by modern standa...
# 7294  Some returning combat veterans suffer scars th...
# 8587  A P-47 Thunderbolt squadron is shown in prepar...
# ...                                                 ...
# 739   Determined teen Din is longing to reconnect wi...
# 1412  Singing and dreaming together, a talented sing...
# 1319  A girl, a dog and her best pal set out to save...
# 765   In this fast-paced and action-packed thriller,...
# 1218  A mom and dad who usually say no decide to say...
#
# [5185 rows x 12 columns]

# %% [markdown]
# Get the top 5 countries by number of titles, sorted by count descending.

# %%
df['country'].value_counts().head(5)
# Out:
# country
# United States     1846
# India              875
# United Kingdom     183
# Canada             107
# Spain               91
# Name: count, dtype: int64

# %% [markdown]
# Get all titles released between 2000 and 2010.

# %%
df[(df['release_year']>=2000) & (df['release_year']<=2010)]
# Out:
#      show_id   type                                              title  \
# 27       s28  Movie                                          Grown Ups
# 48       s49  Movie                                       Training Day
# 51       s52  Movie  InuYasha the Movie 2: The Castle Beyond the Lo...
# 52       s53  Movie  InuYasha the Movie 3: Swords of an Honorable R...
# 53       s54  Movie    InuYasha the Movie 4: Fire on the Mystic Island
# ...      ...    ...                                                ...
# 8793   s8794  Movie                               Yours, Mine and Ours
# 8799   s8800  Movie                                              Zenda
# 8802   s8803  Movie                                             Zodiac
# 8804   s8805  Movie                                         Zombieland
# 8805   s8806  Movie                                               Zoom
#
#                director                                               cast  \
# 27         Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 48        Antoine Fuqua  Denzel Washington, Ethan Hawke, Scott Glenn, T...
# 51    Toshiya Shinohara  Kappei Yamaguchi, Satsuki Yukino, Mieko Harada...
# 52    Toshiya Shinohara  Kappei Yamaguchi, Satsuki Yukino, Koji Tsujita...
# 53    Toshiya Shinohara  Kappei Yamaguchi, Satsuki Yukino, Koji Tsujita...
# ...                 ...                                                ...
# 8793       Raja Gosnell  Dennis Quaid, Rene Russo, Sean Faris, Katija P...
# 8799     Avadhoot Gupte  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# 8802      David Fincher  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8804    Ruben Fleischer  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805       Peter Hewitt  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
#
#             country date_added  release_year rating duration  \
# 27    United States 2021-09-20          2010  PG-13  103 min
# 48    United States 2021-09-16          2001      R  122 min
# 51            Japan 2021-09-15          2002  TV-14   99 min
# 52            Japan 2021-09-15          2003  TV-14   99 min
# 53            Japan 2021-09-15          2004  TV-PG   88 min
# ...             ...        ...           ...    ...      ...
# 8793  United States 2019-11-20          2005     PG   88 min
# 8799          India 2018-02-15          2009  TV-14  120 min
# 8802  United States 2019-11-20          2007      R  158 min
# 8804  United States 2019-11-01          2009      R   88 min
# 8805  United States 2020-01-11          2006     PG   88 min
#
#                                               listed_in  \
# 27                                             Comedies
# 48                                    Dramas, Thrillers
# 51    Action & Adventure, Anime Features, Internatio...
# 52    Action & Adventure, Anime Features, Internatio...
# 53    Action & Adventure, Anime Features, Internatio...
# ...                                                 ...
# 8793                 Children & Family Movies, Comedies
# 8799                       Dramas, International Movies
# 8802                     Cult Movies, Dramas, Thrillers
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
#
#                                             description  content_age  \
# 27    Mourning the loss of their beloved junior high...           15
# 48    A rookie cop with one day to prove himself to ...           24
# 51    With their biggest foe seemingly defeated, Inu...           23
# 52    The Great Dog Demon beaqueathed one of the Thr...           22
# 53    Ai, a young half-demon who has escaped from Ho...           21
# ...                                                 ...          ...
# 8793  When a father of eight and a mother of 10 prep...           20
# 8799  A change in the leadership of a political part...           16
# 8802  A political cartoonist, a crime reporter and a...           18
# 8804  Looking to survive in a world taken over by zo...           16
# 8805  Dragged from civilian life, a former superhero...           19
#
#       is_movie  recent_release  num_genres year_quartile
# 27           1               1           1             1
# 48           1               1           2             1
# 51           1               1           3             1
# 52           1               1           3             1
# 53           1               1           3             1
# ...        ...             ...         ...           ...
# 8793         1               1           2             1
# 8799         1               1           2             1
# 8802         1               1           3             1
# 8804         1               1           2             1
# 8805         1               1           2             1
#
# [801 rows x 17 columns]

# %% [markdown]
# Count how many titles have “Drama” in their listed_in column.

# %%
df['listed_in'].str.contains('Drama', case=False, na=False).sum()
# Out:
# np.int64(2345)

# %% [markdown]
# Part 8 – Insights

# %% [markdown]
# Which country produces the most Netflix content?

# %%
df['country'].value_counts().idxmax()
# Out:
# 'United States'

# %% [markdown]
# Which year had the highest content release?

# %%
df['release_year'].value_counts().idxmax()
# Out:
# np.int64(2017)

# %% [markdown]
# Are Movies or TV Shows more frequent?

# %%
df['type'].value_counts()
# Out:
# type
# Movie      5185
# TV Show     147
# Name: count, dtype: int64

# %% [markdown]
# Which genre appears most frequently on Netflix?

# %%
genres=df['listed_in'].str.split(',').explode().str.strip()
top_genre=genres.value_counts().idxmax()
top_genre
# Out:
# 'International Movies'
